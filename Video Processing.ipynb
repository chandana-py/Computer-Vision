# %% [markdown]
# # Video processing with OpenCV

# %% [markdown]
# ## Objective
# Video Processing is the technique of analyzing ,modifying, or enhancing a video by processing each frame individually to perform tasks such as filtering,object detection,tracking,recognition and visual enhancement.
#
# This notebook demonstrates fundamental video processing techniques using OpenCV, including video capture, frame manipulation, drawing operations, bitwise masking, video recording, playback, and face detection.

# %% [markdown]
# #### 1. Import required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt 
import cv2

# %% [markdown]
# #### 2. Capture images using web camera
# Capture live frames from the default webcam and save an image when the user presses 's'.

# %%
import cv2
#open the default webcam(0)
cap = cv2.VideoCapture(0)
while(True):
    ret,frame = cap.read() #ret is boolean value(true/false)-verify whether it is successfully reading a file , 
    frame is a single image at each instance
    if not ret:    #if frame is not captured properly
        print("failed to grab frame")
        break
    cv2.imshow("webcam - Press 's' to save,'q' to quit",frame)  #show the live webcam feed
    key = cv2.waitKey(1)
    
    if key==ord('s'):  #press 's' to save image
        cv2.imwrite("captured_image.jpg",frame)
        print("image saved successfully!")
    elif key==ord('q'):  #press 'q' to quit
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# image saved successfully!

# %% [markdown]
# ##### 3. Read and Display Video

# %%
import cv2
#open the default webcam(0)
cap = cv2.VideoCapture("car_video.mp4")
while cap.isOpened():
    ret,frame = cap.read() 
    if not ret:   
        break
    cv2.imshow("Playback",frame)  
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### 4. convert video to grayscale

# %%
import cv2
#open the default webcam(0)
cap = cv2.VideoCapture("car_video.mp4")
while True:
    ret,frame = cap.read() 
    if not ret:   
        break
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    cv2.imshow("Grayscale video",gray)  
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### 5. Resize video Frames

# %%
import cv2
#open the default webcam(0)
cap = cv2.VideoCapture(0)
while True:
    ret,frame = cap.read() 
    if not ret:   
        break
    resized_frame = cv2.resize(frame,(700,700))
    cv2.imshow("video manipulation",resized_frame)  
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### 6. Flip video frames (by default cam has horizontal flip)

# %%
import cv2
#open the default webcam(0)
cap = cv2.VideoCapture("car_video.mp4")
while True:
    ret,frame = cap.read() 
    if not ret:   
        break
    flipped = cv2.flip(frame,0)
    cv2.imshow("Flip",flipped)  
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### 7. Draw Rectangle on video

# %%
import cv2
#open the default webcam(0)
cap = cv2.VideoCapture(0)
while True:
    ret,frame = cap.read() 
    if not ret:   
        break
    resized_frame = cv2.resize(frame,(640,480))
    cv2.rectangle(resized_frame,(100,100),(300,400),(255,0,0),15)
    cv2.imshow("Video manipulation",resized_frame)  
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### 8. Draw circle on video

# %%
import cv2
#open the default webcam(0)
cap = cv2.VideoCapture(0)
while True:
    ret,frame = cap.read() 
    if not ret:   
        break
    resized_frame = cv2.resize(frame,(640,480))
    cv2.circle(resized_frame,(350,300),150,(255,0,255),3)
    cv2.imshow("Video manipulation",resized_frame)  
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### 9.Draw line on video

# %%
import cv2
#open the default webcam(0)
cap = cv2.VideoCapture(0)
while True:
    ret,frame = cap.read() 
    if not ret:   
        break
    resized_frame = cv2.resize(frame,(640,480))
    cv2.line(resized_frame,(0,0),(640,480),(0,0,255),15)
    cv2.imshow("Video manipulation",resized_frame)  
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### 10. Add Text on video

# %%
import cv2
#open the default webcam(0)
cap = cv2.VideoCapture(0)
while True:
    ret,frame = cap.read() 
    if not ret:   
        break
    resized_frame = cv2.resize(frame,(640,480))
    cv2.putText(resized_frame,"Welcome to RVITM",(25,40),cv2.FONT_ITALIC,1,(0,0,255),2,cv2.LINE_AA)
    cv2.imshow("Video manipulation",resized_frame)  
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### 11. Bitwise operations on video (Live example) -Masking

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Create black mask
    mask = np.zeros(frame.shape[:2], dtype=np.uint8)

    # Draw white circle mask
    cv2.circle(mask, (frame.shape[1]//2, frame.shape[0]//2), 150, 255, 100)

    # Apply mask
    masked_frame = cv2.bitwise_and(frame, frame, mask=mask)

    cv2.imshow("Original", frame)
    cv2.imshow("Masked Video", masked_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### 12. Bitwise Not on video -negetive of the image/video

# %%
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    
    if not ret:
        break

    inverted = cv2.bitwise_not(frame)

    cv2.imshow("Original", frame)
    cv2.imshow("Inverted Video", inverted)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### 13. Store webcam video - Recording webcam video

# %%
import cv2
cap = cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output.mp4',fourcc,20.0,(640,480))
while cap.isOpened():
    ret,frame = cap.read() 
    if not ret:   
        break
    out.write(frame)
    cv2.imshow("Recording",frame)  
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### 14. Play recorded video

# %%
cap = cv2.VideoCapture("output.mp4")
while cap.isOpened():
    ret,frame = cap.read() 
    if not ret:   
        break
    cv2.imshow("Playback",frame)  
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### 15. Face detection

# %%
# Import the OpenCV library for computer vision operations
import cv2

# Import the time module for FPS (Frames Per Second) calculation
import time

# --------------------------------------------------
# Load Haar Cascade
# --------------------------------------------------

# Load the pre-trained Haar Cascade classifier for frontal face detection
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# Check whether the Haar Cascade file was loaded successfully
if face_cascade.empty():
    print("Error loading Haar Cascade.")
    exit()

# --------------------------------------------------
# Open Webcam
# --------------------------------------------------

# Open the default webcam (0 = primary webcam)
cap = cv2.VideoCapture(0)

# Check whether the webcam opened successfully
if not cap.isOpened():
    print("Unable to open webcam.")
    exit()

# Set webcam resolution to 1280 × 720 (HD)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

# Store the initial time for FPS calculation
prev_time = time.time()

# --------------------------------------------------
# Main Loop
# --------------------------------------------------

# Start an infinite loop to continuously process webcam frames
while True:

    # Capture one frame from the webcam
    # ret   -> True if frame is captured successfully
    # frame -> Captured image
    ret, frame = cap.read()

    # Exit the loop if frame capture fails
    if not ret:
        break

    # Convert the color image into grayscale
    # Haar Cascade works faster on grayscale images
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the grayscale image
    faces = face_cascade.detectMultiScale(

        # Input grayscale image
        gray,

        # Image scaling factor for multi-scale detection
        scaleFactor=1.1,

        # Number of neighboring detections required
        # Higher value = fewer false detections
        minNeighbors=5,

        # Minimum face size to detect
        minSize=(40, 40)
    )

    # Draw Bounding Boxes
    # Loop through every detected face
    for (x, y, w, h) in faces:

        # Draw a green rectangle around the detected face
        cv2.rectangle(

            # Input image
            frame,

            # Top-left corner
            (x, y),

            # Bottom-right corner
            (x + w, y + h),

            # Rectangle color (Green)
            (0, 255, 0),

            # Rectangle thickness
            2
        )

        # Display the label "Face" above the bounding box
        cv2.putText(

            # Input image
            frame,

            # Text to display
            "Face",

            # Text position
            (x, y - 10),

            # Font style
            cv2.FONT_HERSHEY_SIMPLEX,

            # Font size
            0.6,

            # Text color (Green)
            (0, 255, 0),

            # Text thickness
            2
        )

    # --------------------------------------------------
    # FPS Calculation
    # --------------------------------------------------

    # Get the current time
    current_time = time.time()

    # Calculate Frames Per Second (FPS)
    fps = 1 / (current_time - prev_time)

    # Update previous time for the next frame
    prev_time = current_time

    # --------------------------------------------------
    # Display FPS
    # --------------------------------------------------

    # Display FPS on the top-left corner of the frame
    cv2.putText(

        frame,

        # Display FPS with one decimal place
        f"FPS : {fps:.1f}",

        # Position of the text
        (20, 35),

        # Font style
        cv2.FONT_HERSHEY_SIMPLEX,

        # Font size
        0.8,

        # Text color (Blue)
        (255, 0, 0),

        # Text thickness
        2
    )

    # --------------------------------------------------
    # Display Face Count
    # --------------------------------------------------

    # Display the total number of detected faces
    cv2.putText(

        frame,

        # Number of detected faces
        f"Faces : {len(faces)}",

        # Position of the text
        (20, 70),

        # Font style
        cv2.FONT_HERSHEY_SIMPLEX,

        # Font size
        0.8,

        # Text color (Red)
        (0, 0, 255),

        # Text thickness
        2
    )

    # Display the final output window
    cv2.imshow("Haar Cascade Face Detection", frame)

    # Wait for 1 millisecond
    # Exit the program when the user presses the 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# --------------------------------------------------
# Cleanup
# --------------------------------------------------

# Release the webcam resource
cap.release()

# Close all OpenCV windows
cv2.destroyAllWindows()

# %% [markdown]
# ## Task 1 : Face Detection with Face Count
#
# #### Objective
# Detect faces and display the total number of detected faces in real time.

# %%
import cv2

face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    # Draw rectangle around each face
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0,255,0), 2)

    # Display total face count
    cv2.putText(frame,
                "Faces: " + str(len(faces)),
                (20,40),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (0,0,255),
                2)

    cv2.imshow("Face Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Task 2 : Smart Face Detection Dashboard
# #### Objective
# Build a complete face detection system that displays:
# * Face detection
# * Face labels
# * Student name
# * FPS (Frames Per Second)
# * Face count

# %%
import cv2
import time

face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

cap = cv2.VideoCapture(0)

prev_time = time.time()

while True:

    ret, frame = cap.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray,1.3,5)

    current_time = time.time()
    fps = 1/(current_time-prev_time)
    prev_time = current_time

    # Draw rectangle and label
    for (x,y,w,h) in faces:

        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)

        cv2.putText(frame,
                    "Face",
                    (x,y-10),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.7,
                    (255,0,0),
                    2)

    # Student Name
    cv2.putText(frame,
                "Name: Chandana B",
                (20,35),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.8,
                (255,255,0),
                2)

    # FPS
    cv2.putText(frame,
                "FPS: {:.2f}".format(fps),
                (20,70),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.8,
                (0,255,255),
                2)

    # Face Count
    cv2.putText(frame,
                "Faces: {}".format(len(faces)),
                (20,105),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.8,
                (0,0,255),
                2)

    cv2.imshow("Smart Face Detection Dashboard", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Conclusion
# In this notebook, various video processing techniques were implemented using Python and OpenCV.
# The notebook covered webcam image capture, video playback, grayscale conversion, frame resizing, frame flipping, drawing shapes and text on videos, bitwise operations, video recording and playback, real-time face detection, face counting, and a smart face detection dashboard with FPS and face labels.
# These experiments provided practical knowledge of video processing and real-time computer vision applications using OpenCV.
